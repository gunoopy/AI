# %% [markdown]
# # Dynamic Time Warping
# > Distance of Time Series

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

INF = float('inf')

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## Functions
# - DTW : return DTW matrix & path
# - plot_DTW : plot time series data & path

# %%
def DTW(A, B) :
    '''
    A : Time Series 1
    B : Time Series 2
    return DTW Matrix & Path
    '''
    
    # 초기화
    cost = np.array([[INF] * (len(A) + 1) for _ in range(len(B) + 1)])
    cost[0, 0] = 0
    
    # 행렬 채우기
    for i in range(1, len(B) + 1) :
        for j in range(1, len(A) + 1) :
            diff = abs(A[j-1] - B[i-1])
            cost[i,j] = diff + min(cost[i-1,j], cost[i,j-1], cost[i-1,j-1])
            
    # 최적 경로 구하기
    row, col = len(B), len(A)
    path = [(row, col)]
    
    while (row, col) != (1, 1) :
        row, col = min((row-1, col-1), (row-1, col), (row, col-1), key = lambda x : cost[x[0], x[1]])
        path.append((row, col))
    
    return cost, path

def plot_DTW(A, B, path, offset = 5, step = 1) :
    plt.figure(figsize = (16,5))
    
    # DTW x
    plt.subplot(1,2,1)
    plt.plot(A, c = 'orange')
    plt.plot(B + offset, c = 'green')
    idx = range(0, len(A), step)
    plt.vlines(idx, A[idx], (B + offset)[idx], color = 'gray', linewidth = 0.5)
    plt.title('Ordinary')
    
    # DTW
    plt.subplot(1,2,2)
    plt.plot(A, c = 'orange')
    plt.plot(B + offset, c = 'green')
    for x1, x2 in path[::step] :
        x1, x2 = x1-1, x2-1
        plt.plot([x1, x2], [A[x1], B[x2] + offset], c = 'gray', linewidth = 0.5)
    plt.title('DTW')
    plt.show()

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## Data1

# %%
A = np.array([1,2,3,4,2,3])
B = np.array([1,1,3,3,4,3])

cost, path = DTW(A, B)

print('\n---------------')
print('  DTW Matrix')
print('---------------\n')
print(cost)

print('\n--------')
print('  Path')
print('--------\n')
print(' => '.join([str(t) for t in path[::-1]]))

plot_DTW(A, B, path)
# Out:
# ---------------
#   DTW Matrix
# ---------------
#
# [[ 0. inf inf inf inf inf inf]
#  [inf  0.  1.  3.  6.  7.  9.]
#  [inf  0.  1.  3.  6.  7.  9.]
#  [inf  2.  1.  1.  2.  3.  3.]
#  [inf  4.  2.  1.  2.  3.  3.]
#  [inf  7.  4.  2.  1.  3.  4.]
#  [inf  9.  5.  2.  2.  2.  2.]]
#
# --------
#   Path
# --------
#
# (1, 1) => (2, 1) => (3, 2) => (4, 3) => (5, 4) => (6, 5) => (6, 6)

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## Data2

# %%
A = np.concatenate([np.array([1] * 200),
                    np.linspace(1, 10, 50),
                    np.array([10] * 100),
                    np.linspace(10, 13, 10),
                    np.linspace(13, 7, 20),
                    np.linspace(7, 10, 10),
                    np.array([10] * 200)])
A += np.random.randn(len(A)) / 10 # noise

B = np.concatenate([A[-20:] - 9,
                    A[:-20]])

cost, path = DTW(A, B)
plot_DTW(A, B, path, offset = 15, step = 10)

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# - plot DTW matrix

# %%
plt.figure(figsize = (6,6))
sns.heatmap(cost[1:, 1:], cmap = 'Blues', cbar = False)

plt.axis(False)
plt.show()

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## Data3

# %%
X = np.linspace(0, 20, 200)
A = np.sin(X)
B = -A

cost, path = DTW(A, B)
plot_DTW(A, B, path, offset = 3, step = 5)

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# - plot DTW matrix

# %%
plt.figure(figsize = (6,6))
sns.heatmap(cost[1:, 1:], cmap = 'Blues', cbar = False)

plt.axis(False)
plt.show()

# %% [markdown]
# <br/>
# <br/>

# %% [markdown]
# - plot DTW matrix & path

# %%
# make DTW matrix into coordinate
temp = cost[1:, 1:]
coordinate = []
for i in range(temp.shape[0]) :
    for j in range(temp.shape[1]) :
        coordinate.append([i, j, temp[i, j]])
        
coordinate = np.array(coordinate)
coordinate = pd.DataFrame(coordinate, columns = ['X', 'Y', 'W'])

# step = 2
# coordinate = coordinate[(coordinate['X'] % step == 0) & (coordinate['Y'] % step == 0)]

plt.figure(figsize = (10,10))

# plot DTW matrix
sns.scatterplot(data = coordinate, x = 'X', y = 'Y', hue = 'W',
                palette = 'Blues', legend = None, edgecolor = None)

# plot path
step = 3
path2 = np.array(path[::step])
plt.scatter(path2[:, 0], path2[:, 1], c = 'red', s = 10, label = 'Path')

plt.legend()
plt.grid(False)
plt.axis(False)

plt.show()
